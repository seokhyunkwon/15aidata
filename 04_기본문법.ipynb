# %% [markdown]
# # 기본문법!!!!!!!!!!!!!!!111
# ## 기본문법!!!!!!!!!!!!!!!!!!!!!!!!!@!@!@!@!@

# %%
1+1
# Out:
# 2

# %%
# 주석
## 코드 실행에 영향X
## vs code에서 CTRL + / 으로 주석 처리가 가능

# %%
# 들여쓰기
## 공백 2칸 또는 공백 4칸
## 들여쓰기 자체가 문법임

# %%
# 코드블록
## 들여쓰기 기준으로 코드블록을 구성
a=10
if a==10:
  print('10')
  print('입니다')
# Out:
# 10
# 입니다
