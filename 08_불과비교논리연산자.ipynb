# %%
# 불과 비교 연산자 사용하기
print(True)
print(False)
# Out:
# True
# False

# %%
3 > 1
# Out:
# True

# %%
10 == 10
# Out:
# True

# %%
10 != 5
# Out:
# True

# %%
'Python' == 'python'
# Out:
# False

# %%
10 >= 10
# Out:
# True

# %%
1 == 1.0
# Out:
# True

# %%
## ==는 값 자체를 비교 is 는 객체를 비교
1 is 1.0
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_15728\3336455986.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   1 is 1.0
# False

# %%
1 is not 1.0
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_15728\2095918375.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   1 is not 1.0
# True

# %%
print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
print(True ^ True)
print(True ^ False)
print(False ^ True)
print(False ^ False)
# Out:
# False
# True
# True
# False

# %%
not True
# Out:
# False

# %%
not True and False or not False
# Out:
# True

# %%
10 == 10 and 10 != 5
# Out:
# True

# %%
10 > 5 or 10 < 3
# Out:
# True

# %%
not 10 > 5
# Out:
# False

# %%
not 1 is 1.0
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_15728\2506282476.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   not 1 is 1.0
# True

# %%
# 8.3 Quiz 93p
## 1. c
## 2. d
## 3. b, c
## 4. d
# 
# 8.5 Quiz 
# k = 90
# e =81
# m = 86
# s = 80
# k = 90
# e =80
# m = 85
# s = 80

k,e,m,s = map(int, input("성적 입력: ").split() )
print(k>=90 and e>80 and m>85 and s>=80)
# Out:
# False

# %%
(not 10) > 5
print(10 > True)
print(0 >= True)
print(0 >= False)
# Out:
# True
# False
# True
