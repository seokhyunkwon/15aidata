# %%
class Person:
    def greeting(self):
        print('Hello')

james = Person()
james.greeting()
# Out:
# Hello

# %%
# int list dict 등도 다 클래스임

# %%
# 속성 사용하기
class Person:
    def __init__(self):
        self.hello = 'hi'

    def greeting(self):
        print(self.hello)

james = Person()
james.greeting()
# Out:
# hi

# %%
# 인스턴스를 만들 때 값 받기
class Person:
    def __init__(self, name, age, addr):
        self.hello='안녕하세요'
        self.name = name
        self.age = age
        self.addr = addr
    
    def greeting(self):
        print(f'{self.hello}, 저는 {self.name}입니다.')

maria = Person('마리아', 20, '대구')
maria.greeting()

print(maria.name)
print(maria.age)
print(maria.addr)
# Out:
# 안녕하세요, 저는 마리아입니다.
# 마리아
# 20
# 대구

# %%
# 비공개 속성
class Person:
    def __init__(self, name, age, addr, wallet):
        self.name = name
        self.age = age
        self.addr = addr
        self.__wallet = wallet

maria = Person('마리아', 20, '대구', 10000)
maria.__wallet -= 10000
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 10
#       6         self.addr = addr
#       7         self.__wallet = wallet
#       8
#       9 maria = Person('마리아', 20, '대구', 10000)
# ---> 10 maria.__wallet -= 10000
#      11
#      12
#
# AttributeError: 'Person' object has no attribute '__wallet'

# %%
class Person:
    def __init__(self, name, age, addr, wallet):
        self.name = name
        self.age = age
        self.addr = addr
        self.__wallet = wallet

    def pay(self, amount):
        if amount > self.__wallet:
            print('돈이 읎다 ..')
            return
        self.__wallet -= amount
        print(f'이제 {self.__wallet}원 남았네요 ㅋㅋ 거지다!')

maria = Person('마리아', 20, '대구', 3900)
maria.pay(4000)
maria.pay(3000)
# Out:
# 돈이 읎다 ..
# 이제 900원 남았네요 ㅋㅋ 거지다!

# %%
# 34.4 Quiz 445p
## 1. d
## 2. __init__
## 3. e
## 4. c

# %%
# 34.5
class Knight:
    def __init__(self, health, mana, armor):
        self.health = health
        self.mana = mana
        self.armor = armor
    def slash(self):
        print('베기')

x = Knight(health=542.4, mana=210.3, armor=38)
print(x.health, x.mana, x.armor)
x.slash()
# Out:
# 542.4 210.3 38
# 베기

# %%
class Annie:
    def __init__(self, hp, mp, ap):
        self.hp = hp
        self.mp = mp
        self.ap = ap

    def tibbers(self):
        print(f'티버: 피해량 {self.ap * 0.65 + 400}')

hp, mp, ap = map(float, input().split())
x = Annie(hp=hp, mp=mp, ap=ap)
x.tibbers()
# Out:
# 티버: 피해량 6899.35
