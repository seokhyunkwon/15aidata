# %%
# 사칙연산
## + | - | * | /
## 몫과 나머지 // | %

# %%
## 제곱연산자 **

# %%
## 값을 정수로 만들기
print(int(3.3))
print(int(5/2))
print(4/2)
print(int(4/2))
# Out:
# 3
# 2
# 2.0
# 2

# %%
## 객체의 자료형 알아낵
print(type(3))
print(type(3.3))
print(type([]))
print(type((1,)))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'list'>
# <class 'tuple'>

# %%
## 2진수
print(0b110)
# Out:
# 6

# %%
## 8진수
print(0o110)
# Out:
# 72

# %%
## 16진수
print(0x110)
# Out:
# 272

# %%
## 실수 계산
3.5 + 2.1
# Out:
# 5.6

# %%
4.2 + 5
# Out:
# 9.2

# %%
## 값을 실수로 만들기
print(float(5))
print(float(5 + 3))
print(float('5.3'))
# Out:
# 5.0
# 8.0
# 5.3

# %%
## 괄호 사용하기
35 + 1 * 2
# Out:
# 37

# %%
(35 + 1) * 2
# Out:
# 72
