# %%
# 문자열 바꾸기 replace
'Hello, World!'.replace('World', 'Python')
# Out:
# 'Hello, Python!'

# %%
# 문자 바꾸기 maketrans, translate
table = str.maketrans('aeiou', '12345')
'apple'.translate(table)
# Out:
# '1ppl2'

# %%
# 문자열 분리하기 split
'apple pear grape pineapple orange'.split()
# Out:
# ['apple', 'pear', 'grape', 'pineapple', 'orange']

# %%
'apple, pear, grape, pineapple, orange'.split(', ')
# Out:
# ['apple', 'pear', 'grape', 'pineapple', 'orange']

# %%
# 구분열 문자열과 문자열 리스트 연결 join
' '.join(['apple', 'pear', 'grape', 'pineapple', 'orange'])
# Out:
# 'apple pear grape pineapple orange'

# %%
'-'.join(['apple', 'pear', 'grape', 'pineapple', 'orange'])
# Out:
# 'apple-pear-grape-pineapple-orange'

# %%
# 소문자 -> 대문자 upper
'python'.upper()
# Out:
# 'PYTHON'

# %%
# 대 -> 소 lower
'PYTHON'.lower()
# Out:
# 'python'

# %%
# 공백삭제 lstrip rstrip strip
'   Python   '.lstrip()
# Out:
# 'Python   '

# %%
'   Python   '.rstrip()
# Out:
# '   Python'

# %%
'   Python   '.strip()
# Out:
# 'Python'

# %%
# 특정문자 삭제하기 
',Python.,'.lstrip('.,')
# Out:
# 'Python.,'

# %%
',Python.,'.rstrip('.,')
# Out:
# ',Python'

# %%
',python.,'.strip('.,')
# Out:
# 'python'

# %%
# 정렬 ljust rjust center
'python'.ljust(10)
# Out:
# 'python    '

# %%
'python'.rjust(10)
# Out:
# '    python'

# %%
'python'.center(10)
# Out:
# '  python  '

# %%
# 메소드 체이닝
'python'.rjust(10).upper()
# Out:
# '    PYTHON'

# %%
# 문자열 인쪽에 0 채우기
'35'.zfill(4)
# Out:
# '0035'

# %%
'3.5'.zfill(6)
# Out:
# '0003.5'

# %%
'hello'.zfill(10)
# Out:
# '00000hello'

# %%
# 위치 찾기 find rfind 없으면 -1 반환
print('apple pineapple'.find('pl'))
print('apple pineapple'.find('xy'))
# Out:
# 2
# -1

# %%
print('apple pineapple'.rfind('pl'))
print('apple pineapple'.rfind('xy'))
# Out:
# 12
# -1

# %%
# index rindex / index는 없으면 에러 반환
print('apple pineapple'.index('pl'))
# Out:
# 2

# %%
print('apple pineapple'.index('xy'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 print('apple pineapple'.index('xy'))
#
# ValueError: substring not found

# %%
# 개수 세기 count
print('apple pineapple'.count('p'))
print('apple pineapple'.count('pl'))
# Out:
# 5
# 2

# %%
# 문자열 서식 지정자와 포매팅
'I am %s' % 'james'
# Out:
# 'I am james'

# %%
name = 'sh'
'I am %s' % name
# Out:
# 'I am sh'

# %%
'I am %d years old' % 26
# Out:
# 'I am 26 years old'

# %%
'%f' % 2.3
# Out:
# '2.300000'

# %%
'%.2f' % 2.31564
# Out:
# '2.32'

# %%
'%.3f' % 2.3
# Out:
# '2.300'

# %%
'%10s' % 'python'
# Out:
# '    python'

# %%
('%10s' % 'python').strip()
# Out:
# 'python'

# %%
'Today is %d %s' % (3, 'April')
# Out:
# 'Today is 3 April'

# %%
'Hello, {0} {2} {1}'.format('Python', 'Scripts', '3.16')
# Out:
# 'Hello, Python 3.16 Scripts'

# %%
'{0} {0} {1} {1}'.format('Python', 'Scripts')
# Out:
# 'Python Python Scripts Scripts'

# %%
# {} 인덱스 생략 시 순서대로 들어감
'Hello, {} {} {}'.format('Python', 'Scripts', '3.6')
# Out:
# 'Hello, Python Scripts 3.6'

# %%
'Hello, {language} {version}'.format(language='Python', version=3.6)
# Out:
# 'Hello, Python 3.6'

# %%
language='Python'
version=3.6
f'Hello {language} {version}'
# Out:
# 'Hello Python 3.6'

# %%
# format 메소드로 문자열 정렬
'{0:<10}'.format('python')
# Out:
# 'python    '

# %%
'{0:>10}'.format('python')
# Out:
# '    python'

# %%
'{:>10}'.format('python')
# Out:
# '    python'

# %%
# 숫자 개수 맞추기
'%08.2f' % 3.6
# Out:
# '00003.60'

# %%
'{0:08.2f}'.format(150.37)
# Out:
# '00150.37'

# %%
'%03d' % 1
# Out:
# '001'

# %%
'{0:03d}'.format(35)
# Out:
# '035'

# %%
# 채우기와 정렬 조합
'{0:뷁<10}'.format(15)
# Out:
# '15뷁뷁뷁뷁뷁뷁뷁뷁'

# %%
'{0:x>10}'.format(15)
# Out:
# 'xxxxxxxx15'

# %%
# 24.3 Quiz 303p
## 1. a, e
## 2. d
## 3. b, d
## 4. c, d

# %%
# 24.4 
path = 'C:\\Users\\어쩌구\\저쩌구\\띠로리\\프로그램\\파이썬\\버전\\python.exe'
x = path.split('\\')
print(x[-1])
path[path.rfind('\\') + 1:]
# Out:
# python.exe
# 'python.exe'

# %%
# 24.5
words=input().split()
count=0
for word in words:  #for문으로 문자열이 'the'인지 판단
    if (word.strip(",.'")=='the'):
        count+=1  #'the'맞으면 count에 1씩 적립
print(count)
# Out:
# 6

# %%
# 24.6
m=list(map(int,input().split(';')))
m.sort(reverse = True)
for i in m:
    print(f'{i:,}')
# Out:
# 1,304,000
# 367,500
# 250,000
# 158,000
# 128,500
# 83,000
# 59,200
# 51,900
