# %%
# if 조건문 사용
## if 조건식:
## ____코드

# %%
# if 주의점
## = 이 아닌 ==로 써야함
## : 콜론을 빠뜨리는 걸 주의

# %%
# 코드 생략
x=10
if x ==10:
    pass

# %%
# if와 들여쓰기는 중요한 관계

# %%
# 중첩 if 조건문
x=15
if x >= 10:
    print("10이상")
    if x == 15:
        print("x는 15")
    if x == 20:
        print("x는 20")
# Out:
# 10이상
# x는 15

# %%
# 사용자 입력값에 if 사용
x = int(input())
if x == 10:
    print('10입니다')
if x == 20:
    print('20입니다')

# %%
# 13.5 Quiz 163p
## 1. c
## 2. c, j
## 3. a

# 13.6
## if x != 10:
##     print('ok')

# 13.7
x = int(input())
y = input()
if y == 'Cash3000':
    print(x-3000)
if y == 'Cash5000':
    print(x-5000)
# Out:
# 67000
