# %%
# 딕셔너리 만들기
lux = {'health':490, 'mana':334, 'melee':550, 'armor':18.72}
print(lux)
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
# 키 이름은 중복되면 안됨 (가장 뒤의 값을 사용)
lux = {'health':490, 'health': 500 , 'mana':334, 'melee':550, 'armor':18.72}
lux
# Out:
# {'health': 500, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
# 딕셔너리 키의 자료형 (리스트와 딕셔너리를 키로 사용할 수 없음)
## 정수, 실수, 불, 튜플 사용가능
## 값으로는 리스트와 딕셔너리도 사용가능
x = {100 : [12, 32, 50], True : 500, 3.5 : [3.5, 3.5], (1,3): {'health':490, 'health': 500}}
x
# Out:
# {100: [12, 32, 50], True: 500, 3.5: [3.5, 3.5], (1, 3): {'health': 500}}

# %%
# 빈 딕셔너리 만들기
x ={}
y =dict()
print(x)
print(y)
# Out:
# {}
# {}

# %%
lux1 = dict(health=490, mana=334, melee=550, armor=18.72)
lux1
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
lux2 = dict(zip(['health', 'mana', 'melee', 'armor'], [490, 334, 550, 18.72]))
lux2
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
lux3 = dict([('health', 490), ('mana', 334), ('melee', 550), ('armor', 18.72)])
lux3
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
lux4 = dict({'health':490, 'mana':334, 'melee':550, 'armor':18.72})
lux4
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
# 딕셔너리 키에 접근하고 값 할당하기
lux = {'health':490, 'mana':334, 'melee':550, 'armor':18.72}
lux['health']
# Out:
# 490

# %%
lux['health'] = 2037
lux['mana'] = 3000
lux
# Out:
# {'health': 2037, 'mana': 3000, 'melee': 550, 'armor': 18.72}

# %%
lux['mana_regen'] = 3.28
lux
# Out:
# {'health': 2037,
#  'mana': 3000,
#  'melee': 550,
#  'armor': 18.72,
#  'mana_regen': 3.28}

# %%
lux['attack_speed']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 lux['attack_speed']
#
# KeyError: 'attack_speed'

# %%
# 키가 있는지 확인
lux = {'health':490, 'mana':334, 'melee':550, 'armor':18.72}
'health' in lux
# Out:
# True

# %%
'attack_speed' in lux
# Out:
# False

# %%
'attack_speed' not in lux
# Out:
# True

# %%
# 키 개수 구하기
lux = {'health':490, 'mana':334, 'melee':550, 'armor':18.72}
print(len(lux))
print(len({'health':490, 'mana':334, 'melee':550, 'armor':18.72}))
# Out:
# 4

# %%
# 12.3 Quiz 148p
## 1. b
## 2. e
## 3. c
## 4. d

# 12.4
## print(camille['health'])
## print(camille['movement_speed'])

# 12.5
x = input().split()
y = input().split()
z = {}
for i in range(len(x)):
    z[x[i]] = y[i]

print(z)
# Out:
# {'mana': '800', 'hp': '1500', 'atk': '900'}
