# %%
# 사각형 그리기
import turtle as t
t.shape('turtle')

# %%
t.forward(100)

# %%
t.right(90)

# %%
t.forward(100)

# %%
t.forward(100)

# %%
t.right(90)

# %%
t.forward(100)

# %%
for i in range(4):
    t.forward(100)
    t.right(90)

# %%
t.exitonclick()

# %%
t.shape('turtle')
for i in range(100):
    t.forward(100)
    t.right(360 / 100)

# %%
n=6
t.shape('turtle')
t.color('red')
t.begin_fill()
for i in range(n):
    t.forward(100)
    t.right(360 / n)
t.end_fill()

# %%
t.shape('turtle')
t.circle(120)

# %%
n=60
t.shape('turtle')
t.speed('fastest')
for i in range(n):
    t.circle(120)
    t.right(360/n)

# %%
t.shape('turtle')
t.speed('fastest')
for i in range(300):
    t.forward(i)
    t.right(91)

# %%
t.exitonclick()

# %%
# 21.4 Quiz 237p
## 1. d
## 2. d

# 21.5 오각별 그리기
import turtle as t
n=5
t.shape('turtle')
for i in range(n):
    t.forward(100)
    t.right(144)
    t.forward(100)
    t.left(72)

# %%
# 21.6 별 그리기
import turtle as t
 
n, line = map(int, input().split())
t.shape('turtle')
t.speed('fastest')
for i in range(n):
    t.forward(line)
    t.right((360/n)*2)
    t.forward(line)
    t.left(360/n)
