# %%
# elif 
x=20
if x==10:
    print('10')
elif x==20:
    print('20')
# Out:
# 20

# %%
# if else elif 모두 사용 가능

# %%
# 음료수 자판기
button = int(input())
if button==1:
    print('콜라')
elif button==2:
    print('사이다')
elif button==3:
    print('환타')
else:
    print('제공 x')
# Out:
# 사이다

# %%
# 15.2 Quiz 179p
## 1. d, e
## 2. e

# 15.3 
## if 11<=x<=20:
##     print('11~20')
## elif 21<=x<=30:
##     print('21~30')
## else:
##     print('아무것도 해당하지 않음')

# 15.4
age = int(input())
m = 9000
if 7<=age<=12:
    m -= 650
elif 13<=age<=18:
    m -= 1050
elif age>=19:
    m -= 1250
print(m)
# Out:
# 8350
