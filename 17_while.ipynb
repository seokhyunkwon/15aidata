# %%
# while

# %%
i=0
while i<100:
    print('Hello, World!')
    i+=1
# Out:
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# ...

# %%
# 초깃값 1
i=1
while i<=100:
    print('Hello, World!', i)
    i += 1
# Out:
# Hello, World! 1
# Hello, World! 2
# Hello, World! 3
# Hello, World! 4
# Hello, World! 5
# Hello, World! 6
# Hello, World! 7
# Hello, World! 8
# Hello, World! 9
# Hello, World! 10
# Hello, World! 11
# Hello, World! 12
# Hello, World! 13
# Hello, World! 14
# Hello, World! 15
# Hello, World! 16
# Hello, World! 17
# Hello, World! 18
# Hello, World! 19
# Hello, World! 20
# Hello, World! 21
# Hello, World! 22
# Hello, World! 23
# Hello, World! 24
# Hello, World! 25
# Hello, World! 26
# Hello, World! 27
# Hello, World! 28
# Hello, World! 29
# Hello, World! 30
# Hello, World! 31
# Hello, World! 32
# Hello, World! 33
# Hello, World! 34
# Hello, World! 35
# Hello, World! 36
# Hello, World! 37
# Hello, World! 38
# Hello, World! 39
# Hello, World! 40
# Hello, World! 41
# Hello, World! 42
# Hello, World! 43
# Hello, World! 44
# Hello, World! 45
# Hello, World! 46
# Hello, World! 47
# Hello, World! 48
# Hello, World! 49
# Hello, World! 50
# Hello, World! 51
# Hello, World! 52
# Hello, World! 53
# ...

# %%
# 초깃값을 감소시키기
i=100
while i>0:
    print('Hello, World!', i)
    i -=1
# Out:
# Hello, World! 100
# Hello, World! 99
# Hello, World! 98
# Hello, World! 97
# Hello, World! 96
# Hello, World! 95
# Hello, World! 94
# Hello, World! 93
# Hello, World! 92
# Hello, World! 91
# Hello, World! 90
# Hello, World! 89
# Hello, World! 88
# Hello, World! 87
# Hello, World! 86
# Hello, World! 85
# Hello, World! 84
# Hello, World! 83
# Hello, World! 82
# Hello, World! 81
# Hello, World! 80
# Hello, World! 79
# Hello, World! 78
# Hello, World! 77
# Hello, World! 76
# Hello, World! 75
# Hello, World! 74
# Hello, World! 73
# Hello, World! 72
# Hello, World! 71
# Hello, World! 70
# Hello, World! 69
# Hello, World! 68
# Hello, World! 67
# Hello, World! 66
# Hello, World! 65
# Hello, World! 64
# Hello, World! 63
# Hello, World! 62
# Hello, World! 61
# Hello, World! 60
# Hello, World! 59
# Hello, World! 58
# Hello, World! 57
# Hello, World! 56
# Hello, World! 55
# Hello, World! 54
# Hello, World! 53
# Hello, World! 52
# Hello, World! 51
# Hello, World! 50
# Hello, World! 49
# ...

# %%
cnt = int(input("반복 횟수: "))
i=0
while i<cnt:
    print('Hello, World!', i)
    i += 1
# Out:
# Hello, World! 0
# Hello, World! 1
# Hello, World! 2
# Hello, World! 3
# Hello, World! 4
# Hello, World! 5
# Hello, World! 6
# Hello, World! 7
# Hello, World! 8
# Hello, World! 9
# Hello, World! 10
# Hello, World! 11
# Hello, World! 12
# Hello, World! 13
# Hello, World! 14
# Hello, World! 15
# Hello, World! 16
# Hello, World! 17
# Hello, World! 18
# Hello, World! 19
# Hello, World! 20
# Hello, World! 21
# Hello, World! 22
# Hello, World! 23
# Hello, World! 24
# Hello, World! 25
# Hello, World! 26
# Hello, World! 27
# Hello, World! 28
# Hello, World! 29
# Hello, World! 30
# Hello, World! 31
# Hello, World! 32
# Hello, World! 33
# Hello, World! 34
# Hello, World! 35
# Hello, World! 36
# Hello, World! 37
# Hello, World! 38
# Hello, World! 39
# Hello, World! 40
# Hello, World! 41
# Hello, World! 42
# Hello, World! 43
# Hello, World! 44
# Hello, World! 45
# Hello, World! 46
# Hello, World! 47
# Hello, World! 48
# Hello, World! 49
# Hello, World! 50
# Hello, World! 51
# Hello, World! 52
# ...

# %%
# 반복 횟수가 정해지지 않은 경우
import random
random.random()
# Out:
# 0.20737403907864682

# %%
random.randint(1, 6)
# Out:
# 2

# %%
import random
i=0
while i != 3:
    i = random.randint(1, 6)
    print(i)
# Out:
# 3

# %%
# 무한루프 만들기
## while True:
##     print('Hello, World!')

## while 1:

## while 'str':

# %%
# 17.4 Quiz 201p
## 1. b, c
## 2. d
## 3. c
## 4. b, e

# 17.5
## while i <= 32 or j >= 1:
##     print(i, j)
##     i*=2
##     j-=1

# 17.6
m = int(input())
while m >= 1350:
    m -= 1350
    print(m)
# Out:
# 8650
# 7300
# 5950
# 4600
# 3250
# 1900
# 550
