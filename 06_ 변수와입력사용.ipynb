# %%
# 변수 만들기
x = 10
print(x)
# Out:
# 10

# %%
# 변수이름
## 영문과 숫자 사용가능
## 대소문자 구분함
## _ 사용가능
## 특수문자(+ - * / $ @ & % 등)는 사용불가
## 파이썬 예약어(if for while and or 등)는 사용불가

# %%
# 변수의 자료형 알아내기
x = 10
y = "Hello World"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# 변수 여러개를 한 번에 만들기
x, y, z = 10, 20, 30
print(x)
print(y)
print(z)
# Out:
# 10
# 20
# 30

# %%
x = y = z = 10
print(x)
print(y)
print(z)
# Out:
# 10
# 10
# 10

# %%
x,y = y,x

# %%
# 변수로 계산
a = 10
b = 20
c = a + b
c
# Out:
# 30

# %%
# 산술 연산 후 할당 연산자 사용
a = 10
a += 10 # a = a + 10 과 같다
a
# Out:
# 20

# %%
# 입력값을 변수에 저장하기
x = int(input("숫자를 입력하시오"))
x
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 2
#       1 # 입력값을 변수에 저장하기
# ----> 2 x = int(input("숫자를 입력하시오"))
#       3 x
#
# ValueError: invalid literal for int() with base 10: '987 ,                654'

# %%
# 퀴즈 
## 6.5
## 1번 c
## 2번 a, c, e, g, h
## 3번 b, d
## 4번 d

## 6.6
## 1번
# Out:
#   Cell In[16], line 4
#     int x = 10
#         ^
# SyntaxError: invalid syntax

# %%
x, y = map(int, input("숫자 두 개 입력").split(","))

print(x+y)
# Out:
# 975
